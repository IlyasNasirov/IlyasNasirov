# %% [markdown]
# <a href="https://colab.research.google.com/github/IlyasNasirov/IlyasNasirov/blob/main/portfolio_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # Data Science va Sun'iy Intellekt Praktikum
#
# ## 5-MODUL. Machine Learning
#
# ### Portfolio uchun vazifa: Toshkent shahrida uylarning narxini aniqlash.
#
# Ushbu amaliyotda sizning vazifangiz berilgan ma`lumotlar asosida Toshkent shahridagi uylarning narxini aniqlash.

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/housing_data_08-02-2021.csv')
df.head()
# Out:
#                                             location       district  rooms  \
# 0  город Ташкент, Юнусабадский район, Юнусабад 8-...   Юнусабадский      3
# 1  город Ташкент, Яккасарайский район, 1-й тупик ...  Яккасарайский      2
# 2  город Ташкент, Чиланзарский район, Чиланзар 2-...   Чиланзарский      2
# 3  город Ташкент, Чиланзарский район, Чиланзар 9-...   Чиланзарский      3
# 4  город Ташкент, Чиланзарский район, площадь Актепа   Чиланзарский      3
#
#   size  level  max_levels  price
# 0   57      4           4  52000
# 1   52      4           5  56000
# 2   42      4           4  37000
# 3   65      1           4  49500
# 4   70      3           5  55000

# %% [markdown]
# # Ustunlar ta'rifi
# - `location` - sotilayotgan uy manzili
# - `district` - uy joylashgan tuman
# - `rooms` - xonalar soni
# - `size` - uy maydoni (kv.m)
# - `level` - uy joylashgan qavat
# - `max_levels` - ja'mi qavatlar soni
# - `price` - uy narxi
#
# ## Vazifani CRSIP-DM Metolodgiyasi yordamida bajaring.
# <img src="https://i.imgur.com/dzZnnYi.png" alt="CRISP-DM" width="800"/>

# %%
df[df['size'].str.startswith('Площ')]
# Out:
#                                       location     district  rooms  \
# 5347  город Ташкент, Яшнободский район, Дархон  Яшнободский      4
#
#                    size  level  max_levels   price
# 5347  Площадьземли:1сот      3           5  150000

# %%
df.loc[[5347]]
# Out:
#                                       location     district  rooms  \
# 5347  город Ташкент, Яшнободский район, Дархон  Яшнободский      4
#
#                    size  level  max_levels   price
# 5347  Площадьземли:1сот      3           5  150000

# %%
df.loc[5347,'size']=10

# %%
df.size = df['size'].astype(dtype='float64')

# %%
import numpy as np
df.price = df.price.replace('Договорная',np.nan)

# %%
df['price'] = df['price'].astype(dtype='float64')

# %%
df['price'].mean()
# Out:
# np.float64(71334.21042057326)

# %%
df['price'] = df['price'].fillna(df.price.mean())

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
cat_encoded = OneHotEncoder()
cat_encoded.fit_transform(df['district'])
district_encoded = cat_encoded.transform(df[['district']])
district_encoded.to_array()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3717934392.py in <cell line: 0>()
#       1 cat_encoded = OneHotEncoder()
# ----> 2 cat_encoded.fit_transform(df['district'])
#       3 district_encoded = cat_encoded.transform(df[['district']])
#       4 district_encoded.to_array()
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     916         if y is None:
#     917             # fit method of arity 1 (unsupervised transformation)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7565 entries, 0 to 7564
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    7565 non-null   object
#  1   district    7565 non-null   object
#  2   rooms       7565 non-null   int64
#  3   size        7565 non-null   float64
#  4   level       7565 non-null   int64
#  5   max_levels  7565 non-null   int64
#  6   price       7565 non-null   float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 413.8+ KB
